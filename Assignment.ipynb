# %%
import numpy

# %%
import pandas
import numpy

# %%
from PIL import Image

pil_im = Image.open('image2.jpg')

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=524x350 at 0x10D7D5128>

# %%
pil_im = Image.open('image2.jpg').convert('L')

# %%
pil_im
# Out:
# <PIL.Image.Image image mode=L size=524x350 at 0x10D7D5E10>

# %%
filelist = ['image.jpg', 'image2.jpg']

# %%
from PIL import Image
import os

for infile in filelist:
  outfile = os.path.splitext(infile)[0] + ".jpg"
  if infile != outfile:
    try:
      Image.open(infile).save(outfile)
    except IOError:
      print("cannot convert")

# %%
pil_im.thumbnail((128,128))

# %%
box = (100,100,400,400)
region = pil_im.crop(box)

# %%
region = region.transpose(Image.ROTATE_180)
pil_im.paste(region,box)

# %%
out = pil_im.resize((128,128))

# %%
out = pil_im.rotate(180)

# %%
out
# Out:
# <PIL.Image.Image image mode=L size=128x85 at 0x10D7CC4A8>

# %%
from PIL import Image
from pylab import *

im = array(Image.open('image2.jpg'))
imshow(im)

x = [100,100,250,250]
y = [100,250,100,250]

plot(x,y,'r*')
plot(x[:2],y[:2])

title('Plotting: "image2.jpg"')
show()

# %%
from PIL import Image
from pylab import *
im = array(Image.open('image2.jpg').convert('L'))
figure()
gray()
contour(im, origin='image')
axis('equal')
axis('off')
# Out:
# (0.5, 523.5, 0.5, 349.5)

# %%
figure()
hist(im.flatten(),128)
show()

# %%
pil_im = Image.fromarray(im)

# %%
pil_im = Image.fromarray(uint8(im))

# %%
def imresize(im,sz):
  """  Resize an image array using PIL. """
  pil_im = Image.fromarray(uint8(im))

  return array(pil_im.resize(sz))

# %%
def histeq(im,nbr_bins=256):
  """  Histogram equalization of a grayscale image. """

  imhist,bins = histogram(im.flatten(),nbr_bins,normed=True)
  cdf = imhist.cumsum() 
  cdf = 255 * cdf / cdf[-1] 

  im2 = interp(im.flatten(),bins[:-1],cdf)

  return im2.reshape(im.shape), cdf

# %%
from imtools import histeq

im = array(Image.open('image2.jpg').convert('L'))
im2,cdf = imtools.histeq(im)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-cbc460a60869> in <module>()
# ----> 1 from imtools import histeq
#       2
#       3 im = array(Image.open('image2.jpg').convert('L'))
#       4 im2,cdf = imtools.histeq(im)
#
# ModuleNotFoundError: No module named 'imtools'

# %%
import imtools as fq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-5984b15e8a82> in <module>()
# ----> 1 import imtools as fq
#
# ModuleNotFoundError: No module named 'imtools'
